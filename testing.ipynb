# %%
import pandas as pd
import numpy as np
import os
import json
import csv
from pathlib import Path

# %%
train_fake = pd.read_csv(r"C:/Users/Jimmy/OneDrive/Desktop/AI-GenBench/A_NEW_TEST/train_fake_metadata.csv")
val_fake = pd.read_csv(r"C:/Users/Jimmy/OneDrive/Desktop/AI-GenBench/A_NEW_TEST/validation_fake_metadata.csv")

# %%
laion_train = pd.read_csv(r"C:/Users/Jimmy/OneDrive/Desktop/AI-GenBench/A_NEW_TEST/train_laion_metadata.csv")
laion_val = pd.read_csv(r"C:/Users/Jimmy/OneDrive/Desktop/AI-GenBench/A_NEW_TEST/validation_laion_metadata.csv")

# %%
train_fake.head()
# Out:
#                                                image  height  width  label  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...     200    200      1
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...     200    200      1
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...    1024   1024      1
# 3  <PIL.PngImagePlugin.PngImageFile image mode=RG...     256    256      1
# 4  <PIL.PngImagePlugin.PngImageFile image mode=RG...     256    256      1
#
#           generator                                            file_id  \
# 0              LaMa  Artifact/lama/lama/lama-dataset/places/lamaFou...
# 1            BigGAN     Artifact/big_gan/big/biggan-data/894/img008838
# 2        FLUX 1 Dev                   SFHQ-T2I/FLUX1_dev_image_0002579
# 3  Latent Diffusion  DMimageDetection/test/latent-diffusion_noise2i...
# 4      DeepFloyd IF                ELSA_D3/train/row2126498/image_gen0
#
#                description                                    positive_prompt  \
# 0                    place                                                NaN
# 1  wardrobe, closet, press                                                NaN
# 2                     face  Portrait Photo of a 100 year old Fijian gentle...
# 3                  bedroom                                                NaN
# 4                      NaN  A 8k picture of Wild West With Gallows Vector ...
#
#   negative_prompt        conditioning         origin_dataset  \
# 0             NaN               noise               Artifact
# 1             NaN  class/imagenet_894               Artifact
# 2             NaN                text               SFHQ-T2I
# 3             NaN               noise  DMimageDetection/test
# 4             NaN                text          ELSA_D3/train
#
#              paired_real_images               filename
# 0                            []  train\fake\000000.png
# 1                            []  train\fake\000001.png
# 2                            []  train\fake\000002.png
# 3                            []  train\fake\000003.png
# 4  ['LAION-400M/2646974027073']  train\fake\000004.png

# %%
train_fake[train_fake['paired_real_images'] != '[]']
# Out:
#                                                     image  height  width  \
# 4       <PIL.PngImagePlugin.PngImageFile image mode=RG...     256    256
# 15      <PIL.JpegImagePlugin.JpegImageFile image mode=...     512    512
# 22      <PIL.PngImagePlugin.PngImageFile image mode=RG...     480    640
# 29      <PIL.PngImagePlugin.PngImageFile image mode=RG...     480    640
# 34      <PIL.PngImagePlugin.PngImageFile image mode=RG...     704   1344
# ...                                                   ...     ...    ...
# 143891  <PIL.PngImagePlugin.PngImageFile image mode=RG...     360    640
# 143945  <PIL.PngImagePlugin.PngImageFile image mode=RG...     256    256
# 143970  <PIL.JpegImagePlugin.JpegImageFile image mode=...     512    512
# 143983  <PIL.JpegImagePlugin.JpegImageFile image mode=...     512    512
# 143999  <PIL.PngImagePlugin.PngImageFile image mode=RG...    1024   1024
#
#         label                generator  \
# 4           1             DeepFloyd IF
# 15          1     Stable Diffusion 1.5
# 22          1     Stable Diffusion 1.4
# 29          1     Stable Diffusion 1.4
# 34          1  Stable Diffusion XL 1.0
# ...       ...                      ...
# 143891      1  Stable Diffusion XL 1.0
# 143945      1                    Glide
# 143970      1     Stable Diffusion 1.5
# 143983      1     Stable Diffusion 1.5
# 143999      1                 DALL-E 3
#
#                                                   file_id description  \
# 4                     ELSA_D3/train/row2126498/image_gen0         NaN
# 15      DRCT/stable-diffusion-v1-5/train2017/000000012741         NaN
# 22                    ELSA_D3/train/row1504286/image_gen1         NaN
# 29                  ELSA_D3/validation/row2674/image_gen1         NaN
# 34             Synthbuster/stable-diffusion-xl/r0a8b59bbt         NaN
# ...                                                   ...         ...
# 143891                 ELSA_D3/train/row599073/image_gen3         NaN
# 143945  DMimageDetection/test/glide_text2img_valid/ann...         NaN
# 143970  DRCT/stable-diffusion-v1-5/train2017/000000407936         NaN
# 143983  DRCT/stable-diffusion-v1-5/train2017/000000435468         NaN
# 143999                      Synthbuster/dalle3/r08414c5at         NaN
#
#                                           positive_prompt  \
# 4       A 8k picture of Wild West With Gallows Vector ...
# 15      Two children laying in bed together, the girl ...
# 22      A 8k image of Vintage silverplated cigarette b...
# 29      An image of Woman with hair blowing in strong ...
# 34      the pantheon of rome, in the style of luminous...
# ...                                                   ...
# 143891  A Portrait image of collage of little cute gir...
# 143945  People are standing near an airport ticket kiosk.
# 143970       a little cow drinking some milk from its mom
# 143983     A woman with scissors cuts some grapes loose.
# 143999  a white clock tower erect on the street with p...
#
#                                           negative_prompt conditioning  \
# 4                                                     NaN         text
# 15                                                    NaN         text
# 22      signature, cartoon, signature, canvas frame, c...         text
# 29                                                    NaN         text
# 34                                                    NaN         text
# ...                                                   ...          ...
# 143891                                                NaN         text
# 143945                                                NaN         text
# 143970                                                NaN         text
# 143983                                                NaN         text
# 143999                                                NaN         text
#
#                origin_dataset               paired_real_images  \
# 4               ELSA_D3/train     ['LAION-400M/2646974027073']
# 15                       DRCT  ['COCO2017_train/000000012741']
# 22              ELSA_D3/train     ['LAION-400M/2864917012155']
# 29              ELSA_D3/valid     ['LAION-400M/1633057019766']
# 34                Synthbuster             ['RAISE/r0a8b59bbt']
# ...                       ...                              ...
# 143891          ELSA_D3/train     ['LAION-400M/1060975016836']
# 143945  DMimageDetection/test          ['COCO2017_val/361586']
# 143970                   DRCT  ['COCO2017_train/000000407936']
# 143983                   DRCT  ['COCO2017_train/000000435468']
# 143999            Synthbuster             ['RAISE/r08414c5at']
#
#                      filename
# 4       train\fake\000004.png
# 15      train\fake\000015.png
# 22      train\fake\000022.png
# 29      train\fake\000029.png
# 34      train\fake\000034.png
# ...                       ...
# 143891  train\fake\143891.png
# 143945  train\fake\143945.png
# 143970  train\fake\143970.png
# 143983  train\fake\143983.png
# 143999  train\fake\143999.png
#
# [16152 rows x 13 columns]

# %%
laion_train
# Out:
#                    id                                        description  \
# 0         26131007685                        Example of the Track Stitch
# 1       2991477007711  Incredibly, here's somebody I actually recogni...
# 2       2776807013737                     Hardscape Design  Construction
# 3       2700988024311  Check Out This Design For Andersen Law Firm Pl...
# 4       1463557016364                             Earth Science Missions
# ...               ...                                                ...
# 104022  1094881012313  Doux et Smooth Natural Black Unprocessed Hair ...
# 104023  2136182023146  Gama de queijos fatiados com sabores Paiva pac...
# 104024  2010320012831  design small kitchen how to make small kitchen...
# 104025  2010827005528  Cricket Australian ODI captain Steve Smith den...
# 104026  1775822017783  Holabird Pl  HonoraryChicago.com  Architecture...
#
#                                                       url     key   status  \
# 0       http://newstitchaday.com/wp-content/uploads/20...       0  success
# 1       https://images.squarespace-cdn.com/content/53d...       1  success
# 2       http://www.romeroslandscape.com/wp-content/upl...       2  success
# 3       https://i.pinimg.com/originals/b3/72/85/b37285...       4  success
# 4       http://image.slideserve.com/77143/earth-scienc...       5  success
# ...                                                   ...     ...      ...
# 104022  http://image.made-in-china.com/2f1j10uOSaTEYRj...  142009  success
# 104023  https://i.pinimg.com/736x/81/58/72/81587258b82...  142011  success
# 104024  http://tse1.mm.bing.net/th?id=OIP.1Gieekey1j_O...  142012  success
# 104025  https://imageresizer.static9.net.au/fbYauzaa8g...  142014  success
# 104026  https://images.squarespace-cdn.com/content/540...  142016  success
#
#         error_message  width  height  original_width  original_height  \
# 0                 NaN    720     405             720              405
# 1                 NaN    800     533             800              533
# 2                 NaN    960     720             960              720
# 3                 NaN   2108    1731            2108             1731
# 4                 NaN   1024     768            1024              768
# ...               ...    ...     ...             ...              ...
# 104022            NaN    160     160             160              160
# 104023            NaN    736     334             736              334
# 104024            NaN    474     357             474              357
# 104025            NaN    400     225             400              225
# 104026            NaN   1000     750            1000              750
#
#                                                      exif  \
# 0                                                      {}
# 1       {"Image Make": "PENTAX Corporation", "Image Mo...
# 2                                                      {}
# 3                                                      {}
# 4       {"Image Tag 0x5110": "0", "Image Tag 0x5111": ...
# ...                                                   ...
# 104022                                                 {}
# 104023                                                 {}
# 104024  {"Image ExifOffset": "26", "EXIF Tag 0x4000": ...
# 104025                                                 {}
# 104026  {"Image Orientation": "Horizontal (normal)", "...
#
#                                                    sha256  \
# 0       7cd03cbc55900dfc84d5f6e9290e321bf2882ae1e6c8af...
# 1       43798cb33e204cffb38f3f80c0cd1db2ee58c07ecb8969...
# 2       b40f1c5b3ba160a70416c19cd188d93001cec9d1dde82f...
# 3       020c76ebe4baa8fbda386712ffa72aabdc88979e332376...
# 4       0a906af43999293c18ab90cf03734bdf66e491c5af9813...
# ...                                                   ...
# 104022  232e826e064e378ae7b7d9b557cfe3c111eaeae9116290...
# 104023  efd8ab3b94955ff0fbc625fd6a6b4a8ca6d9e76563a64e...
# 104024  66c94aab1d8d5b4ccc00dc3c1035ccf2bab0f771c4ad09...
# 104025  33ba51e7cd054db8775d2e8ea78cdda576cfef97bbcaa0...
# 104026  e066f741205838c382a338d50f59196bdf72c68e1ec2b9...
#
#                        filename
# 0       train\laion\0000000.png
# 1       train\laion\0000001.png
# 2       train\laion\0000002.png
# 3       train\laion\0000003.png
# 4       train\laion\0000004.png
# ...                         ...
# 104022  train\laion\0104022.png
# 104023  train\laion\0104023.png
# 104024  train\laion\0104024.png
# 104025  train\laion\0104025.png
# 104026  train\laion\0104026.png
#
# [104027 rows x 13 columns]
